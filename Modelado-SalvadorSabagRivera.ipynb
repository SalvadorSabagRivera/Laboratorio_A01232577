# %% [markdown]
# # Salvador Sabag Rivera A01232577

# %%
import pandas as pd

datos=pd.read_csv('diabetes.csv')
datos
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
datos.min(axis=0)
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
datos.max(axis=0)
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
datos.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# al analizar los datos recabados por medio de las funciones aplicadas, se concluye que este estudio es bastante valioso para saber el estado de salud de una persona, siendo de bastante utilidad esta base de datos debido a que es una forma mas facil de analizar los datos

# %% [markdown]
# # Análisis Estadístico - Mapas de calor y boxplots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %% [markdown]
# Descripción de los datos (tipos: nominal, ordinal, discreta, continua)

# %%
Descripcion=pd.read_csv('Descripcion.csv')

Descripcion.head()
# Out:
#         Variable          Tipo   SubTipo
# 0    Pregnancies  Cuantitativa  Continua
# 1        Glucose  Cuantitativa  Continua
# 2  BloodPressure  Cuantitativa  Continua
# 3  SkinThickness  Cuantitativa  Continua
# 4        Insulin  Cuantitativa  Discreta

# %% [markdown]
# Exploración de los datos

# %%
datos.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
#  Medidas de tendencia central , promedio, media  y mediana de los datos.

# %%
promedio_age = datos['Age'].mean()
mediana_age =datos['Age'].median()
moda_age = datos['Age'].mode()
print("Promedio_age:",promedio_age)
print("Mediana_age:",mediana_age)
print("Moda_age:",moda_age)
# Out:
# Promedio_age: 33.240885416666664
# Mediana_age: 29.0
# Moda_age: 0    22
# dtype: int64

# %%
promedio_BMI = datos['BMI'].mean()
mediana_BMI =datos['BMI'].median()
moda_BMI = datos['BMI'].mode()
print("Promedio_BMI:",promedio_BMI)
print("Mediana_BMI:",mediana_BMI)
print("Moda_BMI:",moda_BMI)
# Out:
# Promedio_BMI: 31.992578124999977
# Mediana_BMI: 32.0
# Moda_BMI: 0    32.0
# dtype: float64

# %%
promedio_Insulin = datos['Insulin'].mean()
mediana_Insulin =datos['Insulin'].median()
moda_Insulin = datos['Insulin'].mode()
print("Promedio_Insulin:",promedio_Insulin)
print("Mediana_Insulin:",mediana_Insulin)
print("Moda_Insulin:",moda_Insulin)
# Out:
# Promedio_Insulin: 79.79947916666667
# Mediana_Insulin: 30.5
# Moda_Insulin: 0    0
# dtype: int64

# %%
promedio_SkinThickness = datos['SkinThickness'].mean()
mediana_SkinThickness =datos['SkinThickness'].median()
moda_SkinThickness = datos['SkinThickness'].mode()
print("Promedio_SkinThickness:",promedio_SkinThickness)
print("Mediana_SkinThickness:",mediana_SkinThickness)
print("Moda_SkinThickness:",moda_SkinThickness)
# Out:
# Promedio_SkinThickness: 20.536458333333332
# Mediana_SkinThickness: 23.0
# Moda_SkinThickness: 0    0
# dtype: int64

# %%
promedio_BloodPressure = datos['BloodPressure'].mean()
mediana_BloodPressure =datos['BloodPressure'].median()
moda_BloodPressure = datos['BloodPressure'].mode()
print("Promedio_BloodPressure:",promedio_BloodPressure)
print("Mediana_BloodPressure:",mediana_BloodPressure)
print("Moda_BloodPressure:",moda_BloodPressure)
# Out:
# Promedio_BloodPressure: 69.10546875
# Mediana_BloodPressure: 72.0
# Moda_BloodPressure: 0    70
# dtype: int64

# %%
promedio_Glucose = datos['Glucose'].mean()
mediana_Glucose =datos['Glucose'].median()
moda_Glucose= datos['Glucose'].mode()
print("Promedio_Glucose:",promedio_Glucose)
print("Mediana_Glucose:",mediana_Glucose)
print("Moda_Glucose:",moda_Glucose)
# Out:
# Promedio_Glucose: 120.89453125
# Mediana_Glucose: 117.0
# Moda_Glucose: 0     99
# 1    100
# dtype: int64

# %%
promedio_Pregnancies = datos['Pregnancies'].mean()
mediana_Pregnancies =datos['Pregnancies'].median()
moda_Pregnancies = datos['Pregnancies'].mode()
print("Promedio_Pregnancies:",promedio_Pregnancies)
print("Mediana_Pregnancies:",mediana_Pregnancies)
print("Moda_Pregnancies:",moda_Pregnancies)
# Out:
# Promedio_Pregnancies: 3.8450520833333335
# Mediana_Pregnancies: 3.0
# Moda_Pregnancies: 0    1
# dtype: int64

# %%
promedio_DiabetesPedigreeFunction = datos['DiabetesPedigreeFunction'].mean()
mediana_DiabetesPedigreeFunction =datos['DiabetesPedigreeFunction'].median()
moda_DiabetesPedigreeFunction = datos['DiabetesPedigreeFunction'].mode()
print("Promedio_DiabetesPedigreeFunction:",promedio_DiabetesPedigreeFunction)
print("Mediana_DiabetesPedigreeFunction:",mediana_DiabetesPedigreeFunction)
print("Moda_DiabetesPedigreeFunction:",moda_DiabetesPedigreeFunction)
# Out:
# Promedio_DiabetesPedigreeFunction: 0.4718763020833327
# Mediana_DiabetesPedigreeFunction: 0.3725
# Moda_DiabetesPedigreeFunction: 0    0.254
# 1    0.258
# dtype: float64

# %% [markdown]
# Diagramas

# %%
matriz_correlacion = datos.corr().round(2)
plt.figure(figsize=(10, 10))
sns.heatmap(data=matriz_correlacion, annot=True)
# Out:
# <AxesSubplot:>

# %%
correlacion=datos.corr()
plt.figure(figsize=(10, 10))

sns.heatmap(correlacion, vmax=.8, linewidths=0.01,
            square=True,annot=True,cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %%
plt.figure(figsize=(10, 10))
ax = sns.boxplot(x="Outcome", y="Age", 
                data=datos)

ax = sns.stripplot(x="Outcome", y="Age",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %% [markdown]
# Decidií utilizar la variable de outocome con la de la edad debido a que outcome es una variable cuantitativa y age es una variable cualitativa, contrastando de esta manera en el boxplot para obtener el resultado de que tan probable es que se tenga diabetes dependiendo de la edad

# %%
datos.hist(bins=10,figsize=(9,7),grid=False);

# %% [markdown]
# ¿Hay alguna variable que no aporta información? Todas aportan información, pero la que menos aporta a la investigación es la de
# skinthickness debido a que su información es irrelevante para el estudio

# %% [markdown]
# Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué? Como mencioné anteriormente, la variable de skinthickness es la que eliminaría debido a que su información es irrelevante para este estudio

# %% [markdown]
# ¿Existen variables que tengan datos extraños? Sí, la variable de bloodpressure debido a que tiene valor de 0 en algunos casos, lo cual es totalmente irreal debido a que ninguna persona puede tener ese valor

# %% [markdown]
# Si comparas las variables, ¿todas están en rangos similares? No, en su mayoría tienen rangos diferentes
# ¿Crees que esto afecte? No, debido a que para el estudio en algunos casos es necesario que no tengan los mismos rangos, como se puede notar en los diagramas generados

# %% [markdown]
# ¿Puedes encontrar grupos qué se parezcan?¿Qué grupos son estos? Sí, son los que aparecen con valor mas cercano a 1 en la segunda tabla de calor (la de color azul), un ejemplo de ellos es age con pregnancies, skinthickness con outcome, skinthickness
# con BMI, entre otros

# %% [markdown]
# # Preparación de datos

# %%
datos_prep = datos.drop(['BloodPressure','SkinThickness','Outcome'], axis=1)

# %%
datos_prep.head()
# Out:
#    Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0            6      148        0  33.6                     0.627   50
# 1            1       85        0  26.6                     0.351   31
# 2            8      183        0  23.3                     0.672   32
# 3            1       89       94  28.1                     0.167   21
# 4            0      137      168  43.1                     2.288   33

# %%
plt.figure(figsize=(10, 10))
datos1 = datos_prep.loc[:, ['Insulin', 'Glucose']]

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(datos1)
labels = kmeans.predict(datos1)

plt.scatter(datos_prep['Insulin'], datos_prep['Glucose'], c = labels)
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.show()

# %%
plt.figure(figsize=(10, 10))
iner_list = np.empty(10)
for i in range(1,10):
    kmeans2 = KMeans(n_clusters=i)
    kmeans2.fit(datos1)
    iner_list[i] = kmeans2.inertia_

plt.plot(range(0,10), iner_list,'-')
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %%
plt.figure(figsize=(10, 10))
datos1 = datos_prep.loc[:, ['Insulin', 'Glucose']]

from sklearn.cluster import KMeans
kmeans2 = KMeans(n_clusters=3)
kmeans2.fit(datos1)
labels2 = kmeans2.predict(datos1)
list_clusters = np.unique(labels2)
print("Número de clusters:",len(list_clusters))
print("Cluster Centers:",kmeans2.cluster_centers_)

plt.scatter(datos_prep['Insulin'], datos_prep['Glucose'], c = labels2)
plt.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], c='red', marker='x')
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.title('Insulin VS Glucose')
plt.show()
# Out:
# Número de clusters: 3
# Cluster Centers: [[ 14.25303644 114.00404858]
#  [441.28947368 158.44736842]
#  [158.79661017 129.27118644]]

# %%
df = pd.DataFrame({'labels':labels, 'Outcome':datos['Outcome']})
crosstab = pd.crosstab(df['labels'],df['Outcome'])
crosstab
# Out:
# Outcome    0    1
# labels
# 0        421  182
# 1         79   86

# %%
datos_nuevo=datos_prep.copy()

datos_nuevo.loc[:,'Outcome'] = datos['Outcome']
datos_nuevo.loc[:,'cluster'] = labels

datos_nuevo
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 4              0      137      168  43.1                     2.288   33
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      Outcome  cluster
# 0          1        0
# 1          0        0
# 2          1        0
# ...

# %%
sns.set_style('whitegrid')
sns.lmplot(x='Insulin',y='Glucose',data=datos_nuevo, hue='Outcome',
           palette='coolwarm',height=10,aspect=1,fit_reg=False)

# %% [markdown]
# 1 ¿Crees que estos centros puedan ser representativos de los datos? ¿Por qué? Sí, porque representan la correlación que existe
# entre ambas variables

# %% [markdown]
# 2 ¿Cómo obtuviste el valor de k a usar? Por medio de la suma de la distancias al cuadrado de cada objeto del cluster al centroide del objeto

# %% [markdown]
# 3 ¿Los centros serían más representativos si usaras un valor más alto? ¿Más bajo? No, debido a que el cluster tiene un valor de 2, lo cual representa la mejor manera para la variable Outcome debido a que solo tiene 2 posibles resultados (0 y 1)

# %% [markdown]
# 4 ¿Qué distancia tienen los centros entre sí? ¿Hay alguno que este muy cercano a otros? Nos arrojó un resultado que tienen distancias bastante lejana entre ellas

# %% [markdown]
# 5 ¿Qué pasaría con los centros si tuviéramos muchos outliers en el análisis de cajas y bigotes? Provocaría una posicion diferente de los centros, teniendo como resultado clusters imprecisos

# %% [markdown]
# 6 ¿Qué puedes decir de los datos basándose en los centros? Según el estudio realizado y los resultados arrojados, se puede decir que existe una relación entre la Insulina y la presion sanguinea, ayudando a determinar si una persona puede tener diabetes
